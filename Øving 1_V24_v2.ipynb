# %% [markdown]
# # Øving 1

# %% [markdown]
# ## Oppgave 1 - Glattkjøring

# %% [markdown]
# #### a)
#
# På glattkjøring skal bremseavstander for biler testes på vinterføre. Bilen har en hastighet på $30 \text{ km/t}$ når eleven tråkker på bremsen. Bilen kommer til en stopp etter $30 \text{ m}$. Bilens akselerasjon er konstant på stoppestrekningen.
#
# Hvor stor er denne akselerasjonen? Hvor lang tid tar det før bilen stanser?
#
# #### b)
#
# Bremsetesten gjentas, men nå med en dobbelt så stor hastighet på $60 \text{ km/t}$. Anta samme akselerasjon som funnet i a).
#
# Hvor lang er bremsestrekningen og bremsetiden nå i forhold til oppbremsingen i a)?

# %% [markdown]
# ## Oppgave 2 - Hastverk til hytta

# %% [markdown]
# En personbil passerer en politibil, som står i ro, i $100 \text{ km/t}$ og fortsetter med konstant hastighet. Etter $2,0 \text{ s}$ begynner politibilen å kjøre etter med konstant akselerasjon.
#
# Hva må politibilens akselerasjon være for å ta igjen personbilen $1,0 \text{ km}$ etter passeringspunktet?

# %% [markdown]
# ## Oppgave 3 - Lyskryss

# %% [markdown]
# ![bilde.png](attachment:bilde.png)

# %% [markdown]
# Grafen ovenfor oppgir akselerasjonen til en bil som kjører mellom to lyskryss, som en funksjon av tid. Bilen begynner å kjøre fra ro foran det første lyskrysset i $t = 0$, og beveger seg så langs en rett vei til den stanser ved neste lyskryss.
#
# Hvilke av følgende påstander om bevegelsen er riktige?
#
# A. Hastigheten er størst ved $t_1$.
#
# B. Hastigheten er størst ved $t_2$.
#
# C. Hastigheten er størst ved $t_3$.
#
# D. Bilen begynner å bremse ved $t_2$.
#
# E. Bilen begynner å bremse ved $t_3$.
#
# F. Bilen begynner å bremse ved $t_4$.
#
# G. Arealet under grafen mellom $t_1$ og $t_2$ gir tilbakelagt strekning i dette tidsrommet.
#
# H. Arealet under grafen mellom $t_1$ og $t_2$ gir hastighetsendringen i dette tidsrommet.'
#
# I. Stigningstallet til grafen i et punkt gir bilens hastighet i dette tidspunktet.
#
# (J. Bilen har momentant konstant hastighet i $t = 0$.)
#
# (K. Bilen har momentant konstant hastighet i $t_2$.)
#
# (L. Bilen har momentant konstant hastighet i $t_3$.)
#
# (M. Bilen har omtrent konstant hastighet mellom $t_4$ og $t_5$.)
#
# (N. Arealet under grafen fra $t = 0$ til $t_3$ må være lik arealet mellom grafen og x-aksen fra $t_3$ og videre.)
#
# (O. Bilen akselererer både framover og bakover.)
#
# (P. Hvis grafen ble vendt opp ned rundt x-aksen ville bevegelsen fortsatt tatt bilen til neste lyskryss.)

# %% [markdown]
# ## Oppgave 4 - Risikabel stuping

# %% [markdown]
# ![bilde.png](attachment:bilde.png)

# %% [markdown]
# En modig svømmer stuper fra en klippe som har et horisontalt utspring som vist i figuren ovenfor. Utspringet er $1,75 \text{ m}$  bredt og befinner seg $9,00 \text{ m}$ nedenfor toppen av klippen.
#
# Hvor høy horisontal hastighet må svømmeren minst ha idet hun forlater toppen av klippen slik at hun akkurat unngår utspringet?

# %% [markdown]
# ## Oppgave 5 - Fjærkanoner

# %% [markdown]
# #### a)
#
# ![bilde.png](attachment:bilde.png)

# %% [markdown]
# To fjærdrevne kanoner med munninger i samme punkt avfyres samtidig. De skyter kuler med samme startfart, men i hver sin vinkel, som illustrert i figuren ovenfor. Begge kanoner har munning på bakkenivå, samme som blinkene A og B. Den grønne kanonen skyter mer vertikalt mot blink A, mens den blå skyter mer horisontalt mot blink B. Vi ser bort i fra luftmotstand.
#
# Hvilke av følgende påstander er riktige?
#
# A. Den grønne kanonen treffer blink A først.
#
# B. Blinkene treffes samtidig.
#
# C. Den blå kula treffer blink med større fart enn den grønne.
#
# D. Kulene treffer blinkene med samme fart.

# %% [markdown]
# #### b)
#
# ![bilde.png](attachment:bilde.png)

# %% [markdown]
# En annen fjærkanon skyter en kule med startfart $v_0 = 5,3 \text{ m/s}$  mot en blink som ligger i en horisontal avstand
# $x = 2,1 \text{ m}$  og vertikal avstand $y = 0,21 \text{ m}$  fra munningen, som illustrert i figuren ovenfor. Hva må utskytingsvinkelen, $α$, være for at kula skal treffe midt i blinken?
#
# Hint: Trigonometriske likninger kan løses i f.eks. Geogebra, på kalkulator eller i Python (se appendiksen under).

# %% [markdown]
# ## Appendiks: Hvordan finne nullpunkter i Python

# %% [markdown]
# Vi kan bruke fsolve()-funksjonen fra scipy.optimize-pakken til å finne nullpunkter til en funksjon i Python. Vi definerer da først funksjonen vi ønsker å finne nullpunktet til som en funksjon. Vi må også oppgi et startpunkt som 'gjett' på hvor nullpunktet er. Dette har med at fsolve() bruker 'Newtons metode' å gjøre; de interesserte kan lese om hvordan denne metoden fungerer på Wikipedia.

# %% [markdown]
# ![bilde.png](attachment:bilde.png)

# %%
from scipy.optimize import fsolve
import numpy as np

def f(x):
    return np.cos(x) + x

start = 0

sol = fsolve(f, start)

print(sol[0]) #-> -0.73908513
# Out:
# -0.7390851332151607

# %% [markdown]
# Det er viktig å merke seg at vi får bare beregnet ett nullpunkt for et hvert startpunkt. Dersom funksjonen har flere nullpunkter, må vi gi forskjellige startpunkter i nærheten av de ulike nullpunktene for å beregne disse.
