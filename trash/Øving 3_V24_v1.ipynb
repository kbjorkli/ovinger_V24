# %% [markdown]
# # (UTKAST) v4
#
# # Øving 2

# %% [markdown]
# ## Oppgave 1

# %% [markdown]
# ![bilde.png](attachment:bilde.png)

# %% [markdown]
# Et trafikklys veier $218 \text{ N}$. Trafikklyset er hengt opp ved bruk av to tau som begge er spent i en vinkel på $37°$ fra horisontalplanet, slik som vist i figuren ovenfor.
#
# Beregn kreftene som virker langs hvert tau når trafikklyset henger i ro.

# %% [markdown]
# ## Oppgave 2

# %% [markdown]
# ![bilde.png](attachment:bilde.png)

# %% [markdown]
# En kloss henger i en snor som dras i to punkter av to horisontale krefter, $F_1$ og $F_2$, slik at den får to vertikale segmenter og et diagonalt segment i 45 grader, slik som vist på figuren ovenfor. Klossen har en vekt $w = 60,0 \text{ N}$ og henger i ro.
#
# a) Hvor stor er kraften langs det diagonale segmentet?
#
# b) Finn størrelsen på de to horisontale kreftene, $F_1$ og $F_2$.

# %% [markdown]
# ## Oppgave 3

# %% [markdown]
# ![bilde.png](attachment:bilde.png)

# %% [markdown]
# En fast og uniform ball med masse på $45,0 \text{ kg}$  og diameter lik $32,0 \text{ cm}$ hviler mot en vertikal og friksjonsløs vegg. Ballen henger i en tynn vaier med neglisjerbar masse. Avstanden ned langs snora fra opphengspunktet ned til ballens overflate er $30,0 \text{ cm}$.
#
# a)	Tegn kraftdiagrammet for ballen.
#
# b)	Bestem snordraget på ballen.
#
# c)	Med hvor stor kraft trykker ballen mot veggen?

# %% [markdown]
# ## Oppgave 4

# %% [markdown]
# ![bilde.png](attachment:bilde.png)

# %% [markdown]
# En person med masse på $70,0 \text{ kg}$ står stille på en badevekt i en heis. Badevekta viser $72,0 \text{ kg}$ (og er kalibrert riktig!).
#
# Hvilke av følgende påstander *kan* være sanne i en slik situasjon?

# %% [markdown]
# A)	Heisen beveger seg oppover med konstant hastighet.
#
# B)	Heisen akselererer oppover.
#
# C)	Heisen akselererer nedover.
#
# D)	Heisen bremser.
#
# E)	Normalkraften fra underlaget på personen er lik personens tyngde.
#
# F)  Heisen beveger seg i sin maksimale fart.
#
# G)  Heisens fart er 0.

# %% [markdown]
# ## Oppgave 5

# %% [markdown]
# ![bilde.png](attachment:bilde.png)

# %% [markdown]
# En kloss med masse $m$ glir nedover et skråplan hvor det virker friksjon. Skråplanvinkelen $α$ er justert slik at klossen glir nedover med konstant hastighet.
#
# Hvor stort er glidefriksjonstallet $μ_k$ uttrykt ved vinkelen $α$ i denne situasjonen?

# %% [markdown]
# ## Oppgave 6

# %% [markdown]
# ![bilde.png](attachment:bilde.png)

# %% [markdown]
# En berg -og dalbane har en sirkulær løkke med en diameter på $14,0 \text{ m}$. Vognen med passasjerer begynner i posisjon A, $5 \text{ m}$ over bakken, der den har en fart $v_0$. Se figuren ovenfor. I hele denne oppgaven ser vi bort fra både friksjonskrefter og luftmotstand.
#
# a) Tegn en figur som viser kreftene på en passasjer i henholdsvis det øverste og det laveste punktet i loopen.
#
# b) Hva blir normalkraften på en passasjer i det laveste punktet i loopen dersom hastigheten der er $70,0 \text{ km/h}$? Angi svaret i antall ganger tyngdekraften, $G$, som virker på passasjeren (f.eks. $7G$).
#
# c) Hva blir normalkraften på passasjeren i det høyeste punktet i loopen dersom vognen holdt $70,0 \text{ km/h}$ i det laveste punktet? Angi svaret i antall $G$, som i oppgave b).
#
# d) Finn den minste startfarten $v_0$ vogna må ha i posisjon A for at den skal kunne komme seg gjennom loopen uten å miste kontakt med skinnene. *Hint: Hva er normalkraften på vognen i det høyeste punktet i grensetilfellet at vognen kommer seg gjennom loopen?*

# %% [markdown]
# ## Oppgave 7 (Python)

# %% [markdown]
# Denne oppgaven går ut på implementering av en Euler algoritme. (Se jupyter notebook fil på blackboard)
#
# To tvillinger, Alfred og Bjarne, med samme masse på $70 \text{ kg}$, hopper i fallskjerm fra $3500 \text{ m}$. Vi antar rent vertikalt fall og ser bort fra horisontal bevegelse. Vi antar også følgende modell for friksjonskraften:
#
# \begin{equation*}
# F_k = \frac{1}{2} CρAv^2
# \end{equation*}
#
# Såkalt "kvadratisk luftmotstand" fordi kraften er proporsjonal med $v^2$. Lufttettheten $ρ = 1,23 \text{ kg/m}^3$, arealet $A$ er det horisontale tversnittet av personen og $C$ er *luftmotstandskoeffisienten*; en konstant som abstraherer vekk andre friksjonsrelevante fysiske forskjeller. Alfred stuper med hodet først, slik at $A = 0,17 \text{ m}^2$, og har dessuten på seg en snasen og glatt hoppdress slik at $C = 0,7$. Bjarne derimot, faller liggende og får et større areal $A = 1,00 \text{ m}^2$. Bjarne hopper i hverdagsantrekket sitt så derfor blir også $C$ større; $C = 1,0$.
#
# a) Hva er terminalhastighetene Alfred og Bjarne kan oppnå? (Regn ut dette for hånd)
#
# Løs bevegelseligningene numerisk i Python og besvar følgende spørsmål:
#
# b) Hvor lang tid tar det før de har nådd 98% av terminalhastigheten?
#
# c) Hvor mange meter har de falt når de har nådd 98% av terminalhastigheten?
